# %% [markdown]
# Do your work for this exercise in a jupyter notebook named ```matplotlib_exercises```.

# %%
import matplotlib.pyplot as plt
import numpy as np
import math

# %% [markdown]
# 1. Use matplotlib to plot the following equation:
#
# ```y = x^2 − x + 2```
#
# - You'll need to write the code that generates the x and y points.
#
# - Add an anotation for the point 0, 0, the orig
# in.

# %%
x = list(range(-10, ))
y = [x ** 2 - x + 2 for x in x]

plt.scatter(x, y)
plt.plot(x, y, ls = "s")

plt.text(0, 0, '(0,0)', fontsize=10, color='blue')

plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-91-997759a192be> in <module>
#       3
#       4 plt.scatter(x, y)
# ----> 5 plt.plot(x, y, ls = ".")
#       6
#       7 plt.text(0, 0, '(0,0)', fontsize=10, color='blue')
#
# /usr/local/anaconda3/lib/python3.8/site-packages/matplotlib/pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2838 @_copy_docstring_and_deprecators(Axes.plot)
#    2839 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 2840     return gca().plot(
#    2841         *args, scalex=scalex, scaley=scaley,
#    2842         **({"data": data} if data is not None else {}), **kwargs)
#
# /usr/local/anaconda3/lib/python3.8/site-packages/matplotlib/axes/_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1741         """
#    1742         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1743         lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1744         for line in lines:
#    1745             self.add_line(line)
#
# /usr/local/anaconda3/lib/python3.8/site-packages/matplotlib/axes/_base.py in __call__(self, data, *args, **kwargs)
#     271                 this += args[0],
#     272                 args = args[1:]
# --> 273             yield from self._plot_args(this, kwargs)
#     274
#     275     def get_next_color(self):
#
# /usr/local/anaconda3/lib/python3.8/site-packages/matplotlib/axes/_base.py in _plot_args(self, tup, kwargs)
#     416         if ncx > 1 and ncy > 1 and ncx != ncy:
#     417             raise ValueError(f"x has {ncx} columns but y has {ncy} columns")
# --> 418         return [func(x[:, j % ncx], y[:, j % ncy], kw, kwargs)
#     419                 for j in range(max(ncx, ncy))]
#     420
#
# /usr/local/anaconda3/lib/python3.8/site-packages/matplotlib/axes/_base.py in <listcomp>(.0)
#     416         if ncx > 1 and ncy > 1 and ncx != ncy:
#     417             raise ValueError(f"x has {ncx} columns but y has {ncy} columns")
# --> 418         return [func(x[:, j % ncx], y[:, j % ncy], kw, kwargs)
#     419                 for j in range(max(ncx, ncy))]
#     420
#
# /usr/local/anaconda3/lib/python3.8/site-packages/matplotlib/axes/_base.py in _makeline(self, x, y, kw, kwargs)
#     310         default_dict = self._getdefaults(set(), kw)
#     311         self._setdefaults(default_dict, kw)
# --> 312         seg = mlines.Line2D(x, y, **kw)
#     313         return seg
#     314
#
# /usr/local/anaconda3/lib/python3.8/site-packages/matplotlib/lines.py in __init__(self, xdata, ydata, linewidth, linestyle, color, marker, markersize, markeredgewidth, markeredgecolor, markerfacecolor, markerfacecoloralt, fillstyle, antialiased, dash_capstyle, solid_capstyle, dash_joinstyle, solid_joinstyle, pickradius, drawstyle, markevery, **kwargs)
#     361
#     362         self.set_linewidth(linewidth)
# --> 363         self.set_linestyle(linestyle)
#     364         self.set_drawstyle(drawstyle)
#     365
#
# /usr/local/anaconda3/lib/python3.8/site-packages/matplotlib/lines.py in set_linestyle(self, ls)
#    1131                 ls = 'None'
#    1132
# -> 1133             cbook._check_in_list([*self._lineStyles, *ls_mapper_r], ls=ls)
#    1134             if ls not in self._lineStyles:
#    1135                 ls = ls_mapper_r[ls]
#
# /usr/local/anaconda3/lib/python3.8/site-packages/matplotlib/cbook/__init__.py in _check_in_list(_values, **kwargs)
#    2264     for k, v in kwargs.items():
#    2265         if v not in values:
# -> 2266             raise ValueError(
#    2267                 "{!r} is not a valid value for {}; supported values are {}"
#    2268                 .format(v, k, ', '.join(map(repr, values))))
#
# ValueError: '.' is not a valid value for ls; supported values are '-', '--', '-.', ':', 'None', ' ', '', 'solid', 'dashed', 'dashdot', 'dotted'

# %% [markdown]
# 2. Create and label 4 separate charts for the following equations (choose a range for x that makes sense):
#
#     - ```y = √x```
#     - ```y = x^3```
#     - ```y = 2^x```
#     - ```y = 1 / (x + 1)```
# - You can use functions from the ```math``` module to help implement some of the equations above.

# %%
x = list(range(0,10))
y1 = [x ** (1/2) for x in x]

y2 = [x ** 3 for x in x]

y3 = [2 ** x for x in x]

y4 = [1 / (x + 1) for x in x]

plt.plot(x, y1)
plt.show()

plt.plot(x, y2)
plt.show()

plt.plot(x, y3)
plt.show()

plt.plot(x, y4)
plt.show()

# %% [markdown]
# 3. Combine the figures you created in the last step into one large figure with 4 subplots.

# %%
plt.subplot(1, 4, 1)
plt.plot(x, y1)
plt.title('y1')

plt.subplot(1, 4, 2)
plt.plot(x, y2)
plt.title('y2')

plt.subplot(1, 4, 3)
plt.plot(x, y3)
plt.title('y3')

plt.subplot(1, 4, 4)
plt.plot(x, y4)
plt.title('y4')

plt.subplots_adjust(left=None, bottom=None, right=2, top=None, wspace=.25, hspace=1)


plt.show()

# %% [markdown]
# 4. Combine the figures you created in the last step into one figure where each of the 4 equations has a different color for the points. Be sure to include a legend and an appropriate title for the figure.

# %%
plt.subplot(2, 2, 1)
plt.plot(x, y1, c = 'blue')
plt.title('y1')

plt.subplot(2, 2, 2)
plt.plot(x, y2, c = 'orange')
plt.title('y2')

plt.subplot(2, 2, 3)
plt.plot(x, y3, c = 'red')
plt.title('y3')

plt.subplot(2, 2, 4)
plt.plot(x, y4, c = 'green')
plt.title('y4')

plt.suptitle('Matplotlib subplot exercise')
plt.subplots_adjust(left=None, bottom=None, right=1, top=None, wspace=.25, hspace=.5)



plt.show()

# %% [markdown]
# 5. Make a new Jupyter notebook named big_o_notation.ipynb
#
# - Title your chart "Big O Notation"
# - Label your x axis "Elements"
# - Label your y axis "Operations"
# - Label your curves or make a legend for the curves
# - Use LaTex notation where possible
#
#
# Curves to graph
#
# - y = 0x + 1 and label the curve "O(1)"
# - y =
# l
# o
# g
# (
# x
# )
#  and label the curve "O(log n)"
# - y =
# x
#  and label the curve "O(n)"
# - y =
# x
# ∗
# l
# o
# g
# (
# x
# )
#  and label it "O(n log n)"
# - y =
# x
# 2
#  and label it "O(n^2)"
# - y =
# 2
# x
#  and label it "O(2^n)"
# - y =
# n
# !
#  and label it "O(n!)"
# - y =
# n
# n
#  and label it "O(n^n)"

# %% [markdown]
# Bonus Write the code necessary to write your name on a chart. Use box letters.

# %%
plt.title('Matt')

(1,0) , (1,5)
(1,5) , (3,3)
(3,3) , (5,5)
(5,5) , (5,0)
(6,0) , (8,5)
(8,5) , (10,0)
(12,0) , (12,5)
(10,5) , (16,5)
(16,0) , (16,5)
(16,5) , (18,5)


plt.scatter(1,0)
plt.scatter(1,5)

plt.scatter(3,3)
plt.scatter(5,5)

plt.scatter(5,0)
plt.scatter(6,0)

plt.scatter(8,5)
plt.scatter(10,0)
plt.scatter(12,0)
plt.scatter(12,5)
plt.scatter(10,5)


plt.show()

# %% [markdown]
# Bonus: use curves for letters in your name that have curves in them.
